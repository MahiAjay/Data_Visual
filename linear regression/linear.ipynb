# %%
import pandas as pd
import matplotlib.pyplot as plt
#using seaborn to plot
import seaborn as sns
#importing linear regression maths formula
from sklearn.linear_model import LinearRegression
import time
import numpy as np

# %%
url='https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv'

# %%
df = pd.read_csv(url)

# %%
print(df.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# News=df['Newspaper'].tolist()
# Rad=df['Radio'].tolist()
# t_v=df['TV'].tolist()

# %%
# plt.xlabel('News')            
# plt.ylabel('Rad')      
# plt.title('Advertising Data')
# plt.subplot(3,1,1)
# print(plt.scatter(News,Rad,marker='*',color='red'))
# plt.xlabel('t_v')            
# plt.ylabel('Rad')      
# plt.title('Advertising Data')
# plt.subplot(3,1,2)
# print(plt.scatter(Rad,t_v,marker='.',color='black'))
# plt.xlabel('News')            
# plt.ylabel('t_v')      
# plt.title('Advertising Data')
# plt.subplot(3,1,3)
# print(plt.scatter(t_v,Rad,marker='^',color='blue'))
# plt.show()

# %%
# df.plot(subplots=True,layout=(3,3))

# %%
from sklearn import model_selection     # data categoryy
from sklearn import datasets            # for dataset in scikit-learn

# %%
#calling data split library
from sklearn .model_selection import train_test_split
labels=df['Sales']
features=df[['TV','Newspaper','Radio']]

# %%
print(labels)
print(features)
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64
#         TV  Newspaper  Radio
# 0    230.1       69.2   37.8
# 1     44.5       45.1   39.3
# 2     17.2       69.3   45.9
# 3    151.5       58.5   41.3
# 4    180.8       58.4   10.8
# ..     ...        ...    ...
# 195   38.2       13.8    3.7
# 196   94.2        8.1    4.9
# 197  177.0        6.4    9.3
# 198  283.6       66.2   42.0
# 199  232.1        8.7    8.6
#
# [200 rows x 3 columns]

# %%
#plotting of graph with subplots
fig,ax= plt.subplots(3,figsize=(6,6)) # we can use in matplot lib using ax list ax[0]
#seaborn helps in building a statistical approach 
sns.pairplot(df,x_vars=['TV','Newspaper','Radio'],y_vars=['Sales'],kind='scatter')
plt.show()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# X_train,x_test,Y_train,y_test=train_test_split (features,labels,test_size=0.2,)
# X = training (80% training)         
# x = testing  (20% testing)
# Y = training (80% training)
# y = testing  (20% testing)
# Random state specifies the exact data that is taken by both the parties for training and testing
X_train,x_test,Y_train,y_test = train_test_split(features,labels,train_size=0.8)
# ml is an example of pipeline engineering

# %%
# where 1st and 3rd will be given to model/ algo
# calling linear model
model=LinearRegression()

# %%
#passing training data to model
trained_model=model.fit(X_train,Y_train)

# %%
for i in dir (trained_model):
    if 'co' in i:
        print(i)
# Out:
# _parameter_constraints
# coef_
# copy_X
# score
# set_score_request

# %%
#time to predict by passing testing data
predicted_output=trained_model.predict(x_test)
print('predicted_output',predicted_output)
time.sleep(2)
print ('Actual Output',y_test)
# Out:
# predicted_output [21.16073871 24.90290591 13.10375927 15.72464251 12.448072    8.2551206
#  19.35753033 15.80211754 10.53715872 13.94670584 21.779272   16.88685474
#  11.22613965 16.7633589  10.03990047 18.80835563 20.14958173 18.09797581
#   7.03884959 14.69397776 13.29108803 21.05999741 20.06165781  9.18548611
#   7.77265609  9.54282754 18.98925162 14.94153315  9.75270669 19.50330272
#  19.27536912 12.87068132 20.60493843 19.25166064 16.48367266 21.30913009
#  16.87489868 10.19718418 18.78220875 16.37913678]
# Actual Output 104    20.7
# 98     25.4
# 161    13.3
# 9      15.6
# 115    12.6
# 182     8.7
# 131    17.7
# 171    17.5
# 46     10.6
# 37     14.7
# 111    21.8
# 95     16.9
# 1      10.4
# 162    19.9
# 32     13.2
# 23     20.5
# 133    19.6
# 199    18.4
# 22      5.6
# 177    16.7
# 63     14.0
# 69     22.3
# 92     19.4
# 158     7.3
# 172     7.6
# 72      8.8
# 141    19.2
# 123    15.2
# 149    10.1
# 53     21.2
# 139    20.7
# 157    10.1
# 124    19.7
# ...

# %%
#lets plot actual and predicted data points
plt.xlabel('actual sale')
plt.ylabel('predicted sale')
plt.title('Advertising saled data')
plt.scatter(y_test,predicted_output)
plt.plot([min(y_test),max(y_test)],[min(predicted_output),max(predicted_output)],color='red',linestyle='--')
plt.show()

# %%
# Get the coefficients and intercept from the trained model
coefficients = trained_model.coef_
intercept = trained_model.intercept_

# %%
# Plot individual feature vs. Sales
plt.figure(figsize=(12, 4))

for i, feature_name in enumerate(features.columns):
    plt.subplot(1, 3, i + 1)
    plt.scatter(features[feature_name], labels, label='Data')
    plt.plot(features[feature_name], coefficients[i] * features[feature_name] + intercept, color='red', label='Regression Line')
    plt.xlabel(feature_name)
    plt.ylabel('Sales')
    plt.legend()
    plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18468\1682469210.py:11: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# # Load the dataset
# dataset = 'https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv'
# df = pd.read_csv(dataset)

# # Separate features and labels
# labels = df['Sales']
# features = df[['TV', 'Newspaper', 'Radio']]

# # Split the data into training and testing sets
# train_X, test_X, train_Y, test_Y = train_test_split(features, labels, test_size=0.2, random_state=2)

# # Create and fit the linear regression model
# model = LinearRegression()
# train_model = model.fit(train_X, train_Y)

# # Get the coefficients and intercept from the trained model
# coefficients = train_model.coef_
# intercept = train_model.intercept_

# # Plot individual feature vs. Sales
# plt.figure(figsize=(12, 4))

# for i, feature_name in enumerate(features.columns):
#     plt.subplot(1, 3, i + 1)
#     plt.scatter(features[feature_name], labels, label='Data')
#     plt.plot(features[feature_name], coefficients[i] * features[feature_name] + intercept, color='red', label='Regression Line')
#     plt.xlabel(feature_name)
#     plt.ylabel('Sales')
#     plt.legend()

# plt.tight_layout()
# plt.show()
